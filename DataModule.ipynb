# %%
import wbgapi as wb
import pandas as pd

# %% [markdown]
# # Using WBGAPI
# https://pypi.org/project/wbgapi/

# %% [markdown]
# this is just for playing around and doesnt really need to be on git i guess^^

# %%
wb.source.info()
# both World development indicators (WDI) and the Sustainable Development Goals (SGD) are there
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2021-09-15
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2021-10-10
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
wb.series.info(q="WDI")
#wb.economy.info(q='congo')

# %%
# very specific and crazy high dimensional the WDI data...
# We use Sustainable Development goals which are even
wb.db = 46
wb.series.info()
# Out:
# id                        value
# ------------------------  --------------------------------------------------------------------------------------------------------------------------------------------
# AG.LND.FRST.K2            Forest area (sq. km)
# AG.LND.FRST.ZS            Forest area (% of land area)
# AG.YLD.CREL.KG            Cereal yield (kg per hectare)
# BN.CAB.XOKA.GD.ZS         Current account balance (% of GDP)
# BN.KLT.PTXL.CD            Portfolio investment, net (BoP, current US$)
# BX.KLT.DINV.CD.WD         Foreign direct investment, net inflows (BoP, current US$)
# BX.KLT.DINV.WD.GD.ZS      Foreign direct investment, net inflows (% of GDP)
# BX.TRF.PWKR.DT.GD.ZS      Personal remittances, received (% of GDP)
# DT.DOD.DECT.GN.ZS         External debt stocks (% of GNI)
# DT.ODA.ALLD.CD            Net official development assistance and official aid received (current US$)
# DT.ODA.ODAT.CD            Net official development assistance received (current US$)
# ...

# %%
#wb.economy.info()

# %%
wb.data.DataFrame(['NY.GDP.PCAP.KN', "EG.ELC.ACCS.ZS"], wb.region.members('AFR')).head()
# Out:
#                                YR1990         YR1991         YR1992  \
# economy series
# AGO     EG.ELC.ACCS.ZS            NaN            NaN            NaN
#         NY.GDP.PCAP.KN   41911.954952   40943.424998   37308.905332
# BDI     EG.ELC.ACCS.ZS            NaN            NaN            NaN
#         NY.GDP.PCAP.KN  243368.553945  249745.286880  246914.668119
# BEN     EG.ELC.ACCS.ZS            NaN            NaN            NaN
#
#                                YR1993         YR1994         YR1995  \
# economy series
# AGO     EG.ELC.ACCS.ZS            NaN            NaN            NaN
#         NY.GDP.PCAP.KN   27454.962561   26939.386502   29999.576528
# BDI     EG.ELC.ACCS.ZS            NaN            NaN            NaN
#         NY.GDP.PCAP.KN  227015.843385  214586.449299  194684.286653
# BEN     EG.ELC.ACCS.ZS            NaN            NaN            NaN
#
#                                YR1996         YR1997         YR1998  \
# economy series
# ...

# %%
# Out:
#   File "<ipython-input-7-6e7d8ef8e605>", line 1
#     wb.data.
#             ^
# SyntaxError: invalid syntax
